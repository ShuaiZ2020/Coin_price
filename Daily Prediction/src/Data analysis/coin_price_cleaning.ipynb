# %%
import pandas as pd

# %%
# %%time
df_before_jun = pd.read_csv(r'D:\Shuai-Jingbo-Pei-yu\CoinMarketCap_CoinPrice_data\Daily Prediction\src\to_one_&_to_week\total-before-jun.csv')
df_after_jun = pd.read_csv(r'D:\Shuai-Jingbo-Pei-yu\CoinMarketCap_CoinPrice_data\Daily Prediction\src\to_one_&_to_week\total-after-Jun.csv')
df_weekly_net = pd.concat([df_before_jun,df_after_jun]).reset_index()
df_weekly_net
# Out:
# Wall time: 145 ms
#         index       Date Crypto_symbol Predication_month_year    Votes  \
# 0           0  19-Nov-21           BTC                 Apr-22  10223.0
# 1           1  19-Nov-21           BTC                 Dec-21  90538.0
# 2           2  19-Nov-21           BTC                 Feb-22  47700.0
# 3           3  19-Nov-21           BTC                 Jan-22  64201.0
# 4           4  19-Nov-21           BTC                 Mar-22  23403.0
# ...       ...        ...           ...                    ...      ...
# 112291  16795  28-Jun-22          ELON                 Jul-22    138.0
# 112292  16796  28-Jun-22          ELON                 Aug-22     54.0
# 112293  16797  28-Jun-22          ELON                 Sep-22     40.0
# 112294  16798  28-Jun-22          ELON                 Oct-22     28.0
# 112295  16799  28-Jun-22          ELON                 Nov-22      6.0
#
#         Values_median  Values_average
# 0        6.468361e+04    6.497344e+04
# ...

# %% [markdown]
# ### history

# %%
df_total_before_jun = pd.read_csv(r'D:\Shuai-Jingbo-Pei-yu\CoinMarketCap_CoinPrice_data\Daily Prediction\src\to_one_&_to_week\total-before-jun.csv')
df_temp1 = df_total_before_jun.iloc[80274:,:]
df_temp1['Predication_month'] = pd.to_datetime(df_temp1['Predication_month'],format='%B-%y').dt.strftime('%b-%y')
df_temp1.to_csv(r'D:\Shuai-Jingbo-Pei-yu\CoinMarketCap_CoinPrice_data\Daily Prediction\src\to_one_&_to_week\temp.csv',index = False)
# Out:
# C:\Users\szhu76\AppData\Local\Temp\40\ipykernel_328200\836914276.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp1['Predication_month'] = pd.to_datetime(df_temp1['Predication_month'],format='%B-%y').dt.strftime('%b-%y')

# %%
df_total_before_jun = pd.read_csv(r'D:\Shuai-Jingbo-Pei-yu\CoinMarketCap_CoinPrice_data\Daily Prediction\src\to_one_&_to_week\total-before-jun.csv')
df_total_after_jun = pd.read_csv(r'D:\Shuai-Jingbo-Pei-yu\CoinMarketCap_CoinPrice_data\Daily Prediction\src\to_one_&_to_week\total-after-Jun.csv')
df_total = pd.concat([df_total_before_jun,df_total_after_jun])
df_total[(df_total['Crypto_symbol']=='BTC')&(df_total['Predication_month_year']=='Jul-22')]
# Out:
#             Date Crypto_symbol Predication_month_year    Votes  Values_median  \
# 80276  01-May-22           BTC                 Jul-22  13442.0   42920.180000
# 80864  02-May-22           BTC                 Jul-22  14275.0   41507.760207
# 81446  03-May-22           BTC                 Jul-22  14704.0   41730.847897
# 82028  04-May-22           BTC                 Jul-22  14933.0   44032.399019
# 82610  05-May-22           BTC                 Jul-22  14940.0   41982.030054
# 83192  06-May-22           BTC                 Jul-22  14944.0   41691.409232
# 83774  07-May-22           BTC                 Jul-22  14993.0   44855.037653
# 84356  08-May-22           BTC                 Jul-22  15354.0   44040.935754
# 84938  09-May-22           BTC                 Jul-22  15443.0   44119.029551
# 85520  10-May-22           BTC                 Jul-22  15769.0   43529.464416
# 86102  11-May-22           BTC                 Jul-22  16169.0   42208.235006
# ...
